# %% [markdown]
# <a href="https://colab.research.google.com/github/gopireddy99/AD_NLP_assignments/blob/main/Day_12_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DAY - 12**
# # Write a Python script to generate a WordCloud from the text: 'data science machine learning artificial intelligence'. Save the WordCloud as an image.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define the text
text = "data science machine learning artificial intelligence"

# Generate the WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Save the WordCloud as an image
wordcloud.to_file("wordcloud.png")

# Display the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("WordCloud of Text")
plt.show()

print("WordCloud image saved as 'wordcloud.png'")
# Out:
# WordCloud image saved as 'wordcloud.png'
